# %%
import os
import sys
sys.path.append(os.path.abspath('..')) # Add parent directory to path
import warnings
warnings.filterwarnings('ignore') # ignore warnings

# %%
from importlib import reload
from scripts import load_clean_eda
reload(load_clean_eda)
# Out:
# <module 'scripts.load_clean_eda' from 'c:\\ML and DS Files\\Kifiya AI\\Kaim-week-12\\scripts\\load_clean_eda.py'>

# %%
from scripts.load_clean_eda import * # import all functions

# %%
# create an instance
loader = DataLoader('../week 12 data/Data/rossmann-store-sales/train.csv', 
                    '../week 12 data/Data/rossmann-store-sales/test.csv', 
                    '../week 12 data/Data/rossmann-store-sales/store.csv')

# %%
# Loading datasets.
train, test, store = loader.load_data()
# Out:
# 2025-03-06 15:00:13,975 - INFO - Loading datasets...
# 2025-03-06 15:00:14,875 - INFO - Merging store data with train and test...

# %%
# Instantiate the cleaner class for train data cleaning
cleaner = DataCleaner(train)

# %%
cleaner.check_missing_values()
# Out:
# 2025-03-06 15:00:19,705 - INFO - Checking for missing values in the DataFrame.
# 2025-03-06 15:00:19,859 - INFO - Missing values check completed.
#                        Column  Missing Values  Missing Percentage  \
# 0                       Store               0            0.000000
# 1                   DayOfWeek               0            0.000000
# 2                        Date               0            0.000000
# 3                       Sales               0            0.000000
# 4                   Customers               0            0.000000
# 5                        Open               0            0.000000
# 6                       Promo               0            0.000000
# 7                StateHoliday               0            0.000000
# 8               SchoolHoliday               0            0.000000
# 9                   StoreType               0            0.000000
# 10                 Assortment               0            0.000000
# ...

# %%
# fill missing values of merged training data
train = cleaner.fill_missing_values()
# Out:
# 2025-03-06 15:00:23,753 - INFO - Handling missing values...

# %%
cleaner.check_missing_values()
# Out:
# 2025-03-06 15:00:26,671 - INFO - Checking for missing values in the DataFrame.
# 2025-03-06 15:00:26,875 - INFO - Missing values check completed.
#                        Column  Missing Values  Missing Percentage  \
# 0                       Store               0                 0.0
# 1                   DayOfWeek               0                 0.0
# 2                        Date               0                 0.0
# 3                       Sales               0                 0.0
# 4                   Customers               0                 0.0
# 5                        Open               0                 0.0
# 6                       Promo               0                 0.0
# 7                StateHoliday               0                 0.0
# 8               SchoolHoliday               0                 0.0
# 9                   StoreType               0                 0.0
# 10                 Assortment               0                 0.0
# ...

# %%
cleaner_test = DataCleaner(test) # Instantiate the cleaner class for test data cleaning

# %%
cleaner_test.check_missing_values()
# Out:
# 2025-03-06 15:00:32,965 - INFO - Checking for missing values in the DataFrame.
# 2025-03-06 15:00:32,970 - INFO - Missing values check completed.
#                        Column  Missing Values  Missing Percentage  \
# 0                          Id               0            0.000000
# 1                       Store               0            0.000000
# 2                   DayOfWeek               0            0.000000
# 3                        Date               0            0.000000
# 4                        Open              11            0.026772
# 5                       Promo               0            0.000000
# 6                StateHoliday               0            0.000000
# 7               SchoolHoliday               0            0.000000
# 8                   StoreType               0            0.000000
# 9                  Assortment               0            0.000000
# 10        CompetitionDistance              96            0.233645
# ...

# %%
test = cleaner_test.fill_missing_values()
# Out:
# 2025-03-06 15:00:36,673 - INFO - Handling missing values...

# %%
cleaner_test.check_missing_values()
# Out:
# 2025-03-06 15:01:18,368 - INFO - Checking for missing values in the DataFrame.
# 2025-03-06 15:01:18,382 - INFO - Missing values check completed.
#                        Column  Missing Values  Missing Percentage  \
# 0                          Id               0                 0.0
# 1                       Store               0                 0.0
# 2                   DayOfWeek               0                 0.0
# 3                        Date               0                 0.0
# 4                        Open               0                 0.0
# 5                       Promo               0                 0.0
# 6                StateHoliday               0                 0.0
# 7               SchoolHoliday               0                 0.0
# 8                   StoreType               0                 0.0
# 9                  Assortment               0                 0.0
# 10        CompetitionDistance               0                 0.0
# ...

# %%
# Feature Engineering
fe = FeatureEngineer(train)

# %%
# Extracting date features
train = fe.extract_date_features()
# Out:
# 2025-03-06 15:01:27,498 - INFO - Extracting date features...

# %%
# Encoding categorical variables
train = fe.encode_categorical()
# Out:
# 2025-03-06 15:01:31,610 - INFO - Encoding categorical variables...

# %%
# Instantiate data visualizer class
viz = DataVisualizer(train, test)
# Out:
# 2025-03-06 15:01:41,983 - INFO - DataVisualizer initialized with training and test data.

# %%
viz.run_all_visualizations()
# Out:
# 2025-03-06 15:02:10,091 - INFO - Plotted promotion distribution.
# 2025-03-06 15:02:10,775 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-03-06 15:02:11,192 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-03-06 15:02:11,608 - INFO - Plotted sales behavior during holidays.
# 2025-03-06 15:02:12,490 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ...
